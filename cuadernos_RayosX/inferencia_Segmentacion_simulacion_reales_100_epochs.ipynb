# %%
#autoreload
# %load_ext autoreload

# %autoreload 2

import sys
sys.path.append('../')
import torch
import numpy as np

import dataset
import json

from pl_model import SegmentadorMonoclase
import os
from glob import glob
import matplotlib.pyplot as plt
from matplotlib.backends.backend_pdf import PdfPages
import math
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# json_normalizacion="../modelos/normalization_rayosX.json"
# # Read json normalization file
# with open(json_normalizacion, 'r') as file:
#     normalizacion = json.load(file)


# media= normalizacion["medias_norm"]
# dstd= normalizacion["stds_norm"]

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
# def normalizacion_imagen(imgtensor,normalizacion):
#     media=torch.tensor(normalizacion['medias_norm']).unsqueeze(1).unsqueeze(2)
#     dstd=torch.tensor(normalizacion['stds_norm']).unsqueeze(1).unsqueeze(2)
#     imgnormalizado =(imgtensor-media)
#     return imgnormalizado

def predict_image(imgname,modelo,device):
    '''
    NO normaliza la imagen
    ni en tamaño ni en intensidad
    '''
    if isinstance(imgname,str):
        imgtensor = dataset.read_image_rayosX(imgname,2**16-1)
    else:
        imgtensor=imgname
    
    imgnormalizado=imgtensor # torch.log(imgtensor)/math.log(0.2)
    imgnormalizado=imgnormalizado.unsqueeze(0).to(device)
   
    modelo.eval()
    with torch.no_grad():
         logits = modelo(imgnormalizado)
    logits= logits[0,0,:,:]
    probs=torch.nn.functional.sigmoid(logits)
    probs=probs.cpu().numpy()         
    return probs

# %%
modelo= SegmentadorMonoclase(
                            optimizer = 'sgd',  
                            num_channels_in=3,
                            model_version="deeplabv3_resnet50",
                            p_dropout=0.5,
                          )
fichmodelo="../out_models/segmentadorRayosXmonocanal_sinlogaritmo_100_epochs.ckpt"
checkpoint = torch.load(fichmodelo)
modelo.load_state_dict(checkpoint['state_dict'])
modelo.eval()
_=modelo.to(device)
# Out:
# SegmentadorMonoclase Num epochs: None
# MODEL NUM CHHANELS IN 3
# DeepLab Num channels_in: 3

# %%
usuario=os.getenv('USER')
home=os.getenv('HOME')
mscanData= home + '/owc/mscanData/' if usuario == 'aalbiol' else home + 'mscanData/'
# /home/aalbiol/owc/mscanData/rayosX/reales2/recortes_reales
dir_recortes_in=os.path.join(mscanData , 'rayosX/reales2/recortes_reales')
print(dir_recortes_in)
input_files=glob(os.path.join(dir_recortes_in , '*.png'))
print('Number of input files:', len(input_files))   
print('First file:', input_files[0])
# Out:
# /home/aalbiol/owc/mscanData/rayosX/reales2/recortes_reales
# Number of input files: 153
# First file: /home/aalbiol/owc/mscanData/rayosX/reales2/recortes_reales/LOWImg_20240923_083508_00135.png

# %%
root_folder="/home/aalbiol/owc/mscanData/rayosX/pollo"
train_dataset=("../listas_rayosX/buenos/train/train_list.txt","recortes_good")

params={
    'prob_no_change':0.0,
    'min_number_of_defects':1,
    'max_number_of_defects':3,
    'alpha_low': 0.02,
    'alpha_high': 0.04,
    'min_defect_size':40,
    'max_defect_size':150,
    'min_defect_width':2,
    'max_defect_width':5,
    'defect_types':{'FlatLine': 1.0, 'CylLine': 1.0, 'FlatSpline': 1.0, 'CylSpline':1.0}
    }

ds=dataset.DataplacesDataSetSimulaDefectos(root_folder=root_folder,dataplaces=[train_dataset], 
                             max_values=[2**16-1,2**16-1,2**16-1],delimiter=".",terminaciones=[".png"],
                             params_simulacion_defectos=params,transform=None,scale=1.0,monocanal=True,logaritmo=False)
# Out:
# >>>>>>>>>>>> DataplacesDataset terminaciones ['.png'] delimiter .
# >>>>>>>>>> scale in DataSet 1.0
# Datos de normalizacion calculados y guardados en modelos/normalization.json

# %%
im,nombre,mask=ds.__getitem__(0)
print(nombre)
_=plt.subplot(1,2,1)
_=plt.imshow(im.permute((1,2,0)).numpy(),cmap="gray",clim=[0,1])
_=plt.subplot(1,2,2)
_=plt.imshow(mask.numpy(),cmap="gray",clim=[0,1])
# Out:
# ['/home/aalbiol/owc/mscanData/rayosX/pollo/recortes_good/LOWentremusloGood_00085.png']

# %%
k=2
im,nombre,mask=ds.__getitem__(k)
probs=predict_image(im,modelo,device)
_=plt.figure(figsize=(15,5))
_=plt.subplot(1,3,1)
_=plt.imshow(probs,clim=(0,1),cmap='gray')
_=plt.title('Probabilidades')
_=plt.subplot(1,3,2)
plt.imshow(im.permute((1,2,0)).numpy())
_=plt.subplot(1,3,3)
plt.imshow(mask.numpy())

# %% [markdown]
# # Defectos reales

# %%
falsos_positivos=[0, 35, 36, 38, 40, 44, 45, 46, 47, 48, 49, 51,

52, 53, 54, 55, 57, 58, 59, 63, 64, 65, 66, 67, 68, 69, 72, 73, 74, 75, 76, 77, 79, 80,

81, 82, 83, 84, 85, 86, 87, 88, 93,

95, 97, 98, 100,

101, 103, 105, 107, 108, 111, 113, 115, 125, 127, 131, 135, 140, 141, 145]

verdaderos_positivos=[]

for file in input_files:
    numero=int(os.path.basename(file).split('_')[-1].replace(".png",""))
    if numero in falsos_positivos:
        print('Falso positivo:',file)
    else:
        print('Verdadero positivo:',file)
        verdaderos_positivos.append(file)
condefectos=verdaderos_positivos
# Out:
# Falso positivo: /home/aalbiol/owc/mscanData/rayosX/reales2/recortes_reales/LOWImg_20240923_083508_00135.png
# Verdadero positivo: /home/aalbiol/owc/mscanData/rayosX/reales2/recortes_reales/LOWImg_20240923_083508_00012.png
# Falso positivo: /home/aalbiol/owc/mscanData/rayosX/reales2/recortes_reales/LOWImg_20240923_083508_00035.png
# Verdadero positivo: /home/aalbiol/owc/mscanData/rayosX/reales2/recortes_reales/LOWImg_20240923_083508_00071.png
# Falso positivo: /home/aalbiol/owc/mscanData/rayosX/reales2/recortes_reales/LOWImg_20240923_083508_00141.png
# Verdadero positivo: /home/aalbiol/owc/mscanData/rayosX/reales2/recortes_reales/LOWImg_20240923_083508_00039.png
# Falso positivo: /home/aalbiol/owc/mscanData/rayosX/reales2/recortes_reales/LOWImg_20240923_083508_00075.png
# Falso positivo: /home/aalbiol/owc/mscanData/rayosX/reales2/recortes_reales/LOWImg_20240923_083508_00098.png
# Verdadero positivo: /home/aalbiol/owc/mscanData/rayosX/reales2/recortes_reales/LOWImg_20240923_083508_00122.png
# Verdadero positivo: /home/aalbiol/owc/mscanData/rayosX/reales2/recortes_reales/LOWImg_20240923_083508_00090.png
# Verdadero positivo: /home/aalbiol/owc/mscanData/rayosX/reales2/recortes_reales/LOWImg_20240923_083508_00147.png
# Verdadero positivo: /home/aalbiol/owc/mscanData/rayosX/reales2/recortes_reales/LOWImg_20240923_083508_00016.png
# Falso positivo: /home/aalbiol/owc/mscanData/rayosX/reales2/recortes_reales/LOWImg_20240923_083508_00105.png
# Falso positivo: /home/aalbiol/owc/mscanData/rayosX/reales2/recortes_reales/LOWImg_20240923_083508_00087.png
# Verdadero positivo: /home/aalbiol/owc/mscanData/rayosX/reales2/recortes_reales/LOWImg_20240923_083508_00014.png
# Verdadero positivo: /home/aalbiol/owc/mscanData/rayosX/reales2/recortes_reales/LOWImg_20240923_083508_00078.png
# Falso positivo: /home/aalbiol/owc/mscanData/rayosX/reales2/recortes_reales/LOWImg_20240923_083508_00038.png
# Verdadero positivo: /home/aalbiol/owc/mscanData/rayosX/reales2/recortes_reales/LOWImg_20240923_083508_00091.png
# Verdadero positivo: /home/aalbiol/owc/mscanData/rayosX/reales2/recortes_reales/LOWImg_20240923_083508_00149.png
# Falso positivo: /home/aalbiol/owc/mscanData/rayosX/reales2/recortes_reales/LOWImg_20240923_083508_00036.png
# Falso positivo: /home/aalbiol/owc/mscanData/rayosX/reales2/recortes_reales/LOWImg_20240923_083508_00140.png
# Falso positivo: /home/aalbiol/owc/mscanData/rayosX/reales2/recortes_reales/LOWImg_20240923_083508_00145.png
# Verdadero positivo: /home/aalbiol/owc/mscanData/rayosX/reales2/recortes_reales/LOWImg_20240923_083508_00027.png
# Falso positivo: /home/aalbiol/owc/mscanData/rayosX/reales2/recortes_reales/LOWImg_20240923_083508_00081.png
# Falso positivo: /home/aalbiol/owc/mscanData/rayosX/reales2/recortes_reales/LOWImg_20240923_083508_00085.png
# Verdadero positivo: /home/aalbiol/owc/mscanData/rayosX/reales2/recortes_reales/LOWImg_20240923_083508_00124.png
# Falso positivo: /home/aalbiol/owc/mscanData/rayosX/reales2/recortes_reales/LOWImg_20240923_083508_00076.png
# Falso positivo: /home/aalbiol/owc/mscanData/rayosX/reales2/recortes_reales/LOWImg_20240923_083508_00086.png
# Verdadero positivo: /home/aalbiol/owc/mscanData/rayosX/reales2/recortes_reales/LOWImg_20240923_083508_00133.png
# Falso positivo: /home/aalbiol/owc/mscanData/rayosX/reales2/recortes_reales/LOWImg_20240923_083508_00115.png
# Falso positivo: /home/aalbiol/owc/mscanData/rayosX/reales2/recortes_reales/LOWImg_20240923_083508_00111.png
# Verdadero positivo: /home/aalbiol/owc/mscanData/rayosX/reales2/recortes_reales/LOWImg_20240923_083508_00104.png
# Verdadero positivo: /home/aalbiol/owc/mscanData/rayosX/reales2/recortes_reales/LOWImg_20240923_083508_00137.png
# Verdadero positivo: /home/aalbiol/owc/mscanData/rayosX/reales2/recortes_reales/LOWImg_20240923_083508_00050.png
# Verdadero positivo: /home/aalbiol/owc/mscanData/rayosX/reales2/recortes_reales/LOWImg_20240923_083508_00102.png
# Verdadero positivo: /home/aalbiol/owc/mscanData/rayosX/reales2/recortes_reales/LOWImg_20240923_083508_00120.png
# Verdadero positivo: /home/aalbiol/owc/mscanData/rayosX/reales2/recortes_reales/LOWImg_20240923_083508_00151.png
# Verdadero positivo: /home/aalbiol/owc/mscanData/rayosX/reales2/recortes_reales/LOWImg_20240923_083508_00109.png
# Falso positivo: /home/aalbiol/owc/mscanData/rayosX/reales2/recortes_reales/LOWImg_20240923_083508_00053.png
# Falso positivo: /home/aalbiol/owc/mscanData/rayosX/reales2/recortes_reales/LOWImg_20240923_083508_00084.png
# Verdadero positivo: /home/aalbiol/owc/mscanData/rayosX/reales2/recortes_reales/LOWImg_20240923_083508_00042.png
# Verdadero positivo: /home/aalbiol/owc/mscanData/rayosX/reales2/recortes_reales/LOWImg_20240923_083508_00121.png
# Falso positivo: /home/aalbiol/owc/mscanData/rayosX/reales2/recortes_reales/LOWImg_20240923_083508_00063.png
# Falso positivo: /home/aalbiol/owc/mscanData/rayosX/reales2/recortes_reales/LOWImg_20240923_083508_00103.png
# Verdadero positivo: /home/aalbiol/owc/mscanData/rayosX/reales2/recortes_reales/LOWImg_20240923_083508_00126.png
# Verdadero positivo: /home/aalbiol/owc/mscanData/rayosX/reales2/recortes_reales/LOWImg_20240923_083508_00034.png
# Verdadero positivo: /home/aalbiol/owc/mscanData/rayosX/reales2/recortes_reales/LOWImg_20240923_083508_00096.png
# Verdadero positivo: /home/aalbiol/owc/mscanData/rayosX/reales2/recortes_reales/LOWImg_20240923_083508_00011.png
# Verdadero positivo: /home/aalbiol/owc/mscanData/rayosX/reales2/recortes_reales/LOWImg_20240923_083508_00022.png
# Verdadero positivo: /home/aalbiol/owc/mscanData/rayosX/reales2/recortes_reales/LOWImg_20240923_083508_00123.png
# Verdadero positivo: /home/aalbiol/owc/mscanData/rayosX/reales2/recortes_reales/LOWImg_20240923_083508_00061.png
# Falso positivo: /home/aalbiol/owc/mscanData/rayosX/reales2/recortes_reales/LOWImg_20240923_083508_00083.png
# Verdadero positivo: /home/aalbiol/owc/mscanData/rayosX/reales2/recortes_reales/LOWImg_20240923_083508_00144.png
# Verdadero positivo: /home/aalbiol/owc/mscanData/rayosX/reales2/recortes_reales/LOWImg_20240923_083508_00128.png
# Falso positivo: /home/aalbiol/owc/mscanData/rayosX/reales2/recortes_reales/LOWImg_20240923_083508_00064.png
# Verdadero positivo: /home/aalbiol/owc/mscanData/rayosX/reales2/recortes_reales/LOWImg_20240923_083508_00021.png
# Verdadero positivo: /home/aalbiol/owc/mscanData/rayosX/reales2/recortes_reales/LOWImg_20240923_083508_00142.png
# Falso positivo: /home/aalbiol/owc/mscanData/rayosX/reales2/recortes_reales/LOWImg_20240923_083508_00101.png
# Falso positivo: /home/aalbiol/owc/mscanData/rayosX/reales2/recortes_reales/LOWImg_20240923_083508_00127.png
# Verdadero positivo: /home/aalbiol/owc/mscanData/rayosX/reales2/recortes_reales/LOWImg_20240923_083508_00003.png
# Falso positivo: /home/aalbiol/owc/mscanData/rayosX/reales2/recortes_reales/LOWImg_20240923_083508_00073.png
# Verdadero positivo: /home/aalbiol/owc/mscanData/rayosX/reales2/recortes_reales/LOWImg_20240923_083508_00009.png
# Falso positivo: /home/aalbiol/owc/mscanData/rayosX/reales2/recortes_reales/LOWImg_20240923_083508_00069.png
# Falso positivo: /home/aalbiol/owc/mscanData/rayosX/reales2/recortes_reales/LOWImg_20240923_083508_00125.png
# Falso positivo: /home/aalbiol/owc/mscanData/rayosX/reales2/recortes_reales/LOWImg_20240923_083508_00066.png
# Verdadero positivo: /home/aalbiol/owc/mscanData/rayosX/reales2/recortes_reales/LOWImg_20240923_083508_00062.png
# Falso positivo: /home/aalbiol/owc/mscanData/rayosX/reales2/recortes_reales/LOWImg_20240923_083508_00131.png
# Verdadero positivo: /home/aalbiol/owc/mscanData/rayosX/reales2/recortes_reales/LOWImg_20240923_083508_00060.png
# Verdadero positivo: /home/aalbiol/owc/mscanData/rayosX/reales2/recortes_reales/LOWImg_20240923_083508_00150.png
# Verdadero positivo: /home/aalbiol/owc/mscanData/rayosX/reales2/recortes_reales/LOWImg_20240923_083508_00119.png
# Verdadero positivo: /home/aalbiol/owc/mscanData/rayosX/reales2/recortes_reales/LOWImg_20240923_083508_00017.png
# Verdadero positivo: /home/aalbiol/owc/mscanData/rayosX/reales2/recortes_reales/LOWImg_20240923_083508_00029.png
# Verdadero positivo: /home/aalbiol/owc/mscanData/rayosX/reales2/recortes_reales/LOWImg_20240923_083508_00138.png
# Verdadero positivo: /home/aalbiol/owc/mscanData/rayosX/reales2/recortes_reales/LOWImg_20240923_083508_00070.png
# Verdadero positivo: /home/aalbiol/owc/mscanData/rayosX/reales2/recortes_reales/LOWImg_20240923_083508_00002.png
# Falso positivo: /home/aalbiol/owc/mscanData/rayosX/reales2/recortes_reales/LOWImg_20240923_083508_00067.png
# Falso positivo: /home/aalbiol/owc/mscanData/rayosX/reales2/recortes_reales/LOWImg_20240923_083508_00100.png
# Verdadero positivo: /home/aalbiol/owc/mscanData/rayosX/reales2/recortes_reales/LOWImg_20240923_083508_00106.png
# Falso positivo: /home/aalbiol/owc/mscanData/rayosX/reales2/recortes_reales/LOWImg_20240923_083508_00049.png
# Verdadero positivo: /home/aalbiol/owc/mscanData/rayosX/reales2/recortes_reales/LOWImg_20240923_083508_00006.png
# Verdadero positivo: /home/aalbiol/owc/mscanData/rayosX/reales2/recortes_reales/LOWImg_20240923_083508_00099.png
# Verdadero positivo: /home/aalbiol/owc/mscanData/rayosX/reales2/recortes_reales/LOWImg_20240923_083508_00037.png
# Verdadero positivo: /home/aalbiol/owc/mscanData/rayosX/reales2/recortes_reales/LOWImg_20240923_083508_00032.png
# Falso positivo: /home/aalbiol/owc/mscanData/rayosX/reales2/recortes_reales/LOWImg_20240923_083508_00079.png
# Falso positivo: /home/aalbiol/owc/mscanData/rayosX/reales2/recortes_reales/LOWImg_20240923_083508_00055.png
# Falso positivo: /home/aalbiol/owc/mscanData/rayosX/reales2/recortes_reales/LOWImg_20240923_083508_00082.png
# Verdadero positivo: /home/aalbiol/owc/mscanData/rayosX/reales2/recortes_reales/LOWImg_20240923_083508_00030.png
# Falso positivo: /home/aalbiol/owc/mscanData/rayosX/reales2/recortes_reales/LOWImg_20240923_083508_00048.png
# Verdadero positivo: /home/aalbiol/owc/mscanData/rayosX/reales2/recortes_reales/LOWImg_20240923_083508_00023.png
# Verdadero positivo: /home/aalbiol/owc/mscanData/rayosX/reales2/recortes_reales/LOWImg_20240923_083508_00007.png
# Verdadero positivo: /home/aalbiol/owc/mscanData/rayosX/reales2/recortes_reales/LOWImg_20240923_083508_00024.png
# Falso positivo: /home/aalbiol/owc/mscanData/rayosX/reales2/recortes_reales/LOWImg_20240923_083508_00047.png
# Verdadero positivo: /home/aalbiol/owc/mscanData/rayosX/reales2/recortes_reales/LOWImg_20240923_083508_00013.png
# Verdadero positivo: /home/aalbiol/owc/mscanData/rayosX/reales2/recortes_reales/LOWImg_20240923_083508_00015.png
# Falso positivo: /home/aalbiol/owc/mscanData/rayosX/reales2/recortes_reales/LOWImg_20240923_083508_00051.png
# Verdadero positivo: /home/aalbiol/owc/mscanData/rayosX/reales2/recortes_reales/LOWImg_20240923_083508_00117.png
# Verdadero positivo: /home/aalbiol/owc/mscanData/rayosX/reales2/recortes_reales/LOWImg_20240923_083508_00041.png
# Verdadero positivo: /home/aalbiol/owc/mscanData/rayosX/reales2/recortes_reales/LOWImg_20240923_083508_00153.png
# Verdadero positivo: /home/aalbiol/owc/mscanData/rayosX/reales2/recortes_reales/LOWImg_20240923_083508_00114.png
# Verdadero positivo: /home/aalbiol/owc/mscanData/rayosX/reales2/recortes_reales/LOWImg_20240923_083508_00018.png
# Falso positivo: /home/aalbiol/owc/mscanData/rayosX/reales2/recortes_reales/LOWImg_20240923_083508_00059.png
# Falso positivo: /home/aalbiol/owc/mscanData/rayosX/reales2/recortes_reales/LOWImg_20240923_083508_00072.png
# Verdadero positivo: /home/aalbiol/owc/mscanData/rayosX/reales2/recortes_reales/LOWImg_20240923_083508_00136.png
# Falso positivo: /home/aalbiol/owc/mscanData/rayosX/reales2/recortes_reales/LOWImg_20240923_083508_00040.png
# Verdadero positivo: /home/aalbiol/owc/mscanData/rayosX/reales2/recortes_reales/LOWImg_20240923_083508_00134.png
# Verdadero positivo: /home/aalbiol/owc/mscanData/rayosX/reales2/recortes_reales/LOWImg_20240923_083508_00019.png
# Verdadero positivo: /home/aalbiol/owc/mscanData/rayosX/reales2/recortes_reales/LOWImg_20240923_083508_00110.png
# Verdadero positivo: /home/aalbiol/owc/mscanData/rayosX/reales2/recortes_reales/LOWImg_20240923_083508_00132.png
# Falso positivo: /home/aalbiol/owc/mscanData/rayosX/reales2/recortes_reales/LOWImg_20240923_083508_00046.png
# Verdadero positivo: /home/aalbiol/owc/mscanData/rayosX/reales2/recortes_reales/LOWImg_20240923_083508_00004.png
# Verdadero positivo: /home/aalbiol/owc/mscanData/rayosX/reales2/recortes_reales/LOWImg_20240923_083508_00028.png
# Verdadero positivo: /home/aalbiol/owc/mscanData/rayosX/reales2/recortes_reales/LOWImg_20240923_083508_00152.png
# Falso positivo: /home/aalbiol/owc/mscanData/rayosX/reales2/recortes_reales/LOWImg_20240923_083508_00107.png
# Falso positivo: /home/aalbiol/owc/mscanData/rayosX/reales2/recortes_reales/LOWImg_20240923_083508_00065.png
# Falso positivo: /home/aalbiol/owc/mscanData/rayosX/reales2/recortes_reales/LOWImg_20240923_083508_00097.png
# Falso positivo: /home/aalbiol/owc/mscanData/rayosX/reales2/recortes_reales/LOWImg_20240923_083508_00088.png
# Verdadero positivo: /home/aalbiol/owc/mscanData/rayosX/reales2/recortes_reales/LOWImg_20240923_083508_00094.png
# Verdadero positivo: /home/aalbiol/owc/mscanData/rayosX/reales2/recortes_reales/LOWImg_20240923_083508_00130.png
# Verdadero positivo: /home/aalbiol/owc/mscanData/rayosX/reales2/recortes_reales/LOWImg_20240923_083508_00116.png
# Falso positivo: /home/aalbiol/owc/mscanData/rayosX/reales2/recortes_reales/LOWImg_20240923_083508_00095.png
# Verdadero positivo: /home/aalbiol/owc/mscanData/rayosX/reales2/recortes_reales/LOWImg_20240923_083508_00056.png
# Falso positivo: /home/aalbiol/owc/mscanData/rayosX/reales2/recortes_reales/LOWImg_20240923_083508_00108.png
# Verdadero positivo: /home/aalbiol/owc/mscanData/rayosX/reales2/recortes_reales/LOWImg_20240923_083508_00005.png
# Verdadero positivo: /home/aalbiol/owc/mscanData/rayosX/reales2/recortes_reales/LOWImg_20240923_083508_00031.png
# Verdadero positivo: /home/aalbiol/owc/mscanData/rayosX/reales2/recortes_reales/LOWImg_20240923_083508_00001.png
# Verdadero positivo: /home/aalbiol/owc/mscanData/rayosX/reales2/recortes_reales/LOWImg_20240923_083508_00148.png
# Verdadero positivo: /home/aalbiol/owc/mscanData/rayosX/reales2/recortes_reales/LOWImg_20240923_083508_00146.png
# Verdadero positivo: /home/aalbiol/owc/mscanData/rayosX/reales2/recortes_reales/LOWImg_20240923_083508_00139.png
# Verdadero positivo: /home/aalbiol/owc/mscanData/rayosX/reales2/recortes_reales/LOWImg_20240923_083508_00033.png
# Falso positivo: /home/aalbiol/owc/mscanData/rayosX/reales2/recortes_reales/LOWImg_20240923_083508_00113.png
# Verdadero positivo: /home/aalbiol/owc/mscanData/rayosX/reales2/recortes_reales/LOWImg_20240923_083508_00129.png
# Falso positivo: /home/aalbiol/owc/mscanData/rayosX/reales2/recortes_reales/LOWImg_20240923_083508_00057.png
# Falso positivo: /home/aalbiol/owc/mscanData/rayosX/reales2/recortes_reales/LOWImg_20240923_083508_00080.png
# Verdadero positivo: /home/aalbiol/owc/mscanData/rayosX/reales2/recortes_reales/LOWImg_20240923_083508_00026.png
# Verdadero positivo: /home/aalbiol/owc/mscanData/rayosX/reales2/recortes_reales/LOWImg_20240923_083508_00112.png
# Verdadero positivo: /home/aalbiol/owc/mscanData/rayosX/reales2/recortes_reales/LOWImg_20240923_083508_00010.png
# Falso positivo: /home/aalbiol/owc/mscanData/rayosX/reales2/recortes_reales/LOWImg_20240923_083508_00077.png
# Verdadero positivo: /home/aalbiol/owc/mscanData/rayosX/reales2/recortes_reales/LOWImg_20240923_083508_00008.png
# Verdadero positivo: /home/aalbiol/owc/mscanData/rayosX/reales2/recortes_reales/LOWImg_20240923_083508_00118.png
# Falso positivo: /home/aalbiol/owc/mscanData/rayosX/reales2/recortes_reales/LOWImg_20240923_083508_00045.png
# Falso positivo: /home/aalbiol/owc/mscanData/rayosX/reales2/recortes_reales/LOWImg_20240923_083508_00058.png
# Verdadero positivo: /home/aalbiol/owc/mscanData/rayosX/reales2/recortes_reales/LOWImg_20240923_083508_00143.png
# Verdadero positivo: /home/aalbiol/owc/mscanData/rayosX/reales2/recortes_reales/LOWImg_20240923_083508_00043.png
# Falso positivo: /home/aalbiol/owc/mscanData/rayosX/reales2/recortes_reales/LOWImg_20240923_083508_00074.png
# Verdadero positivo: /home/aalbiol/owc/mscanData/rayosX/reales2/recortes_reales/LOWImg_20240923_083508_00020.png
# Verdadero positivo: /home/aalbiol/owc/mscanData/rayosX/reales2/recortes_reales/LOWImg_20240923_083508_00025.png
# Verdadero positivo: /home/aalbiol/owc/mscanData/rayosX/reales2/recortes_reales/LOWImg_20240923_083508_00089.png
# Verdadero positivo: /home/aalbiol/owc/mscanData/rayosX/reales2/recortes_reales/LOWImg_20240923_083508_00092.png
# Falso positivo: /home/aalbiol/owc/mscanData/rayosX/reales2/recortes_reales/LOWImg_20240923_083508_00044.png
# Falso positivo: /home/aalbiol/owc/mscanData/rayosX/reales2/recortes_reales/LOWImg_20240923_083508_00054.png
# Falso positivo: /home/aalbiol/owc/mscanData/rayosX/reales2/recortes_reales/LOWImg_20240923_083508_00068.png
# Falso positivo: /home/aalbiol/owc/mscanData/rayosX/reales2/recortes_reales/LOWImg_20240923_083508_00052.png
# Falso positivo: /home/aalbiol/owc/mscanData/rayosX/reales2/recortes_reales/LOWImg_20240923_083508_00093.png

# %%
k=9
imlineal=dataset.read_image_rayosX(condefectos[k],2**16-1)
#Convertir a monocanal
imlineal=torch.mean(imlineal,dim=0,keepdim=True)
imlineal=torch.concat([imlineal]*3,dim=0)
print(imlineal.shape)
imgtensor=imlineal
probs=predict_image(imgtensor,modelo,device)
_=plt.subplot(1,2,1)
_= plt.imshow(imgtensor.permute((1,2,0)).detach().cpu().numpy())
_=plt.subplot(1,2,2)
img= plt.imshow(probs)
# Out:
# torch.Size([3, 550, 632])

# %%
from tqdm import tqdm
with PdfPages('pdfs/reales_100_epochs.pdf') as pdf:
    for k in tqdm(range(0,len(condefectos))):
        imlineal=dataset.read_image_rayosX(condefectos[k],2**16-1)
        #Convertir a monocanal
        imlineal=torch.mean(imlineal,dim=0,keepdim=True)
        imlineal=torch.concat([imlineal]*3,dim=0)
        #print(imlineal.shape)
        imgtensor=imlineal
        probs=predict_image(imgtensor,modelo,device)
        bn=os.path.basename(condefectos[k])
        _=plt.figure(figsize=(15,10))
        _=plt.subplot(1,2,1)
        _= plt.imshow(imgtensor.permute((1,2,0)).detach().cpu().numpy())
        _=plt.title(bn)
        _=plt.subplot(1,2,2)
        _= plt.imshow(probs,clim=(0,1),cmap='gray')
        fig = plt.gcf()
        pdf.savefig(fig)
        plt.close(fig)
# Out:
#   0%|          | 0/92 [00:00<?, ?it/s]
# 100%|██████████| 92/92 [00:14<00:00,  6.15it/s]
